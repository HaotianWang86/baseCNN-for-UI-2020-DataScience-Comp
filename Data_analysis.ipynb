# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt #using pyplot to display images
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
### Train Data
Train_data = np.load('Competition_Train_data_8000.npy') 
Train_data.shape

### Train Label
Train_label = np.load('Competition_Train_label_8000.npy') 
Train_label.shape
# Out:
# (8000,)

# %%
g = sns.countplot(Train_label)

# %%
### Show first 16 images
for i in range(16):
    plt.subplot(4, 4, i+1)
    plt.imshow(Train_data[i], cmap = 'Greys_r')
plt.show()

# %%
### show first 16 labels
for i in range(16):
    print(Train_label[i])
# Out:
# 9
# 2
# 7
# 9
# 8
# 14
# 7
# 15
# 8
# 10
# 1
# 1
# 9
# 6
# 3
# 1

# %% [markdown]
# ### All the labels are correct

# %%
# test data
Test_data = np.load('Competition_Problems.npy') 
Test_data.shape
# Out:
# (20000, 64, 384)

# %%
# Train data 
for i in range(30):
    plt.imshow(Train_data[i], cmap = 'Greys_r')
    plt.show()

# %%
### Show first 30 images
for i in range(30):
    plt.plot(i)
    plt.imshow(Test_data[i], cmap = 'Greys_r')
    plt.show()

# %%
## part 1

# crop 60:130
for i in range(30):
    img = Test_data[i][:,60:130]
    img = cv2.resize(img, (64,64))
    plt.imshow(img, cmap = 'Greys_r')
    plt.show()

# %%
# part 2

# crop 250 - 314
for i in range(30):
    img = Test_data[i][:,250:322]
    img = cv2.resize(img, (64,64))
    plt.imshow(img, cmap = 'Greys_r')
    plt.show()

# %%
# crop 315:384
for i in range(30):
    img = Test_data[i][:,315:384]
    img = cv2.resize(img, (64,64))
    plt.imshow(img, cmap = 'Greys_r')
    plt.show()
